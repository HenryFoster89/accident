# %%
import pandas as pd
from utils.utils import gruppa
pd.set_option('display.max_columns', None)

# %%
df = pd.read_json(r'data\accident_2025.json')

# %%
df_group = gruppa(df)

# %%
df
# Out:
#        state_number state_name  consecutive_number  \
# 0                 1    Alabama               10115
# 1                 1    Alabama               10191
# 2                 1    Alabama               10192
# 3                 1    Alabama               10204
# 4                 1    Alabama               10231
# ...             ...        ...                 ...
# 10421            15     Hawaii              150071
# 10422            15     Hawaii              150072
# 10423            15     Hawaii              150073
# 10424            15     Hawaii              150079
# 10425            17   Illinois              170004
#
#        number_of_vehicle_forms_submitted_all  \
# 0                                          1
# 1                                          1
# 2                                          1
# 3                                          1
# 4                                          1
# ...                                      ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10426 entries, 0 to 10425
# Data columns (total 90 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   state_number                                                 10426 non-null  int64
#  1   state_name                                                   10426 non-null  object
#  2   consecutive_number                                           10426 non-null  int64
#  3   number_of_vehicle_forms_submitted_all                        10426 non-null  int64
#  4   number_of_motor_vehicles_in_transport_mvit                   10426 non-null  int64
#  5   number_of_parked_working_vehicles                            10426 non-null  int64
#  6   number_of_forms_submitted_for_persons_not_in_motor_vehicles  10426 non-null  int64
# ...

# %%
df.describe()
# Out:
#        state_number  consecutive_number  \
# count  10426.000000        10426.000000
# mean      27.542778       276100.692979
# std       16.476989       164719.066940
# min        1.000000        10002.000000
# 25%       12.000000       121884.250000
# 50%       27.500000       275185.500000
# 75%       45.000000       450102.750000
# max       56.000000       560130.000000
#
#        number_of_vehicle_forms_submitted_all  \
# count                           10426.000000
# mean                                1.660176
# std                                 1.170009
# min                                 1.000000
# 25%                                 1.000000
# 50%                                 1.000000
# 75%                                 2.000000
# max                                58.000000
#
#        number_of_motor_vehicles_in_transport_mvit  \
# count                                10426.000000
# mean                                     1.624880
# ...
